# %%
# Install missingno package for missing data visualization
# %pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Objectives:
#
# Finding the % of Churn Customers and customers that keep in with the active services.
#
# Analysing the data in terms of various features responsible for customer Churn
#
# Finding a most suited machine learning model for correct classification of Churn and non churn customers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("c:/Users/ANJAN/OneDrive/Documents/Anjan Datasets/customer_churn_data.xlsx")
data.head()
# Out:
#    CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.info()  # to the data types of the columns and the number of non-null values
# .info provides a concise numerical summary of the DataFrame, 
# including the number of non-null values and data types of the each column
# numerical summary is use for understanding the structure of the machine learning dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        7043 non-null   object
#  1   Gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   Tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe()  # to get the statistical summary of the data
# Out:
#        SeniorCitizen       Tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.isnull().any().any()   # to check if there are any missing values in the data
# Out:
# np.False_

# %%
data.shape
# Out:
# (7043, 21)

# %% [markdown]
# # Visualize missing values

# %%
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
data = data.drop(["CustomerID"], axis = 1) # axis = 1 means cloumn wise operation
data.head()
# Out:
#    Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
data[data["TotalCharges"] == " "] 
#it is found that there are 11 rows with empty values in the TotalCharges column
# Out:
#       Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
data["TotalCharges"] = pd.to_numeric(data["TotalCharges"], errors = "coerce") 
data.isnull().sum() # coerce will replace the empty values with NaN
# Out:
# Gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# Tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data[data["Tenure"]== 0] 
# it means that the customer has not stayed with the company for a month
# Out:
#       Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
data.drop(labels = data[data["Tenure"] == 0].index, axis = 0, inplace = True)
# drop the rows where the tenure is 0

# %%
data.fillna(data["TotalCharges"].mean()) 
# it will replace the NaN values with the mean of the TotalCharges column
# Out:
#       Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
data['TotalCharges'] = pd.to_numeric(data.TotalCharges, errors='coerce')
data.isnull().sum()  # after replacing the NaN values with the mean of the TotalCharges column
# Out:
# Gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# Tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.SeniorCitizen.unique()  #to get the unique values of the SeniorCitizen column
# Out:
# array([0, 1])

# %%
# map method works on the Series objects and is used to substitute 
# each value in a Series with another value
data.SeniorCitizen = data.SeniorCitizen.map({0 : "No", 1 : "Yes"})
data.head()
# Out:
#    Gender SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
data.InternetService.describe(include = ["Object", "Bool"])
# to get the statistical summary of the InternetService column
# Out:
# count            7032
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %% [markdown]
# **What is Exploratory Data Analysis (EDA)?**
#
# Exploratory Data Analysis (EDA) is an important first step in data science projects. It involves looking at and visualizing data to understand its main features, find patterns, and discover how different parts of the data are connected.
#
# EDA helps to spot any unusual data or outliers and is usually done before starting more detailed statistical analysis or building models
#
# EDA helps to identify hidden patterns and relationships between different data points, which help us in and model building.

# %% [markdown]
#  ---
# **Churn distribution: 26.6 % of customers switched to another firm.**

# %%
# Categories
type = ["No", "Yes"]

# Value counts for churn
churn_counts = data['Churn'].value_counts()

# Colors from seaborn
colors = sns.color_palette("pastel")
myexplode = [0, 0.1]
# Create pie chart (with a hole for donut style)
fig, ax = plt.subplots(figsize=(6,6))
wedges, texts, autotexts = ax.pie(
    churn_counts,
    labels=type,
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    explode = myexplode,
    shadow=True,
    wedgeprops=dict(width=0.6)  # <-- donut effect
)

# Central text
plt.text(0, 0, "Churn", ha='center', va='center', fontsize=16, fontweight='bold')
 # ha means horizontal alignment and va means vertical alignment
plt.title("Churn Distributions Percentages", fontsize=16, fontweight="bold")
plt.legend()
plt.show()

# %%
data.Churn[data.Churn == "No"].groupby(by = data.Gender).count()
# Out:
# Gender
# Female    2544
# Male      2619
# Name: Churn, dtype: int64

# %%
data.Churn[data.Churn == "Yes"].groupby(by = data.Gender).count()
# Out:
# Gender
# Female    939
# Male      930
# Name: Churn, dtype: int64

# %% [markdown]
#  ---
# **Churn distribution with respect to gender:**
#
# There is negligible difference in customer percentage/count who chnaged the service provider. Both genders behaved in similar fashion when it comes to migrating to another service provider/firm.`

# %%
#  Gender Distribution 
labels_gender = ["Female (Churn)", "Male (Churn)", "Female (No Churn)", "Male (No Churn)"]
values_gender = [939, 930, 2544, 2619]

colors_gender = sns.color_palette("rainbow", 4)
myexplode = [0.08, 0.08, 0.08, 0.08]

plt.figure(figsize=(7,7))
plt.pie(values_gender,
        labels= labels_gender,
        autopct= '%1.1f%%',
        startangle= 90,
        colors=colors_gender,
        explode = myexplode,
        shadow= True,
        wedgeprops=dict(width=0.6),
        textprops= {"fontsize":12})
plt.text(0, 0, "Gender", ha='center', va='center', fontsize=20, fontweight='bold')
plt.title("Churn Distribution w.r.t Gender: Male(M), Female(F)", fontsize=14, y=1.05, fontweight= "bold") # y= 1.05 means to move the title up
plt.axis("equal")
plt.legend(loc= "upper right")
plt.show()

# %% [markdown]
# # Customers with monthly contract are more likely to churn

# %% [markdown]
#  ---
# **Customer Contract distribution:**
#
# About 75% of customer with Month-to-Month Contract opted to move out as compared to 13% of customrs with One Year Contract and 3% with Two Year Contract

# %%
sns.set_theme(style="whitegrid")

# Set figure size
plt.figure(figsize=(8,6))

# Grouped bar chart: x = Churn, hue = Contract
ax = sns.countplot(data=data, x="Churn", hue="Contract")
# countplot is used to show the counts of observations in each categorical bin using bars of different colors

# for loop to Add value labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type="edge", fontsize=10) # label_type= "edge" places the labels at the edge of the bars

# Title & labels
plt.title("Customer Churn w.r.t. Contract Distribution", fontsize=14, fontweight="bold")
plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
# **Payment Methods:**
#
# Major customers who moved out were having Electronic Check as Payment Method. Customers who opted for Credit-Card automatic transfer or Bank Automatic Transfer and Mailed Check as Payment Method were less likely to move out.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

labels = data['PaymentMethod'].unique()
values = data['PaymentMethod'].value_counts()
colors = sns.color_palette("muted", 4)

myexplode = [0.08, 0.08, 0.08, 0.08]
plt.figure(figsize=(7,7))

plt.pie(values,
        labels= labels,
        autopct= '%1.1f%%',
        startangle= 90,
        colors=colors,
        explode = myexplode,
        shadow= True,        
        wedgeprops=dict(width=0.6),
        textprops= {"fontsize":12}
)
plt.text(0, 0, "Payment Mode", ha='center', va='center', fontsize=15, fontweight='bold')
plt.title("Payment Method Distribution", fontsize= 14,  y=1.05, fontweight= "bold")
plt.axis("equal")
plt.legend(loc= "upper left")
plt.show()

# %%
import matplotlib.pyplot as plt

# crosstab is used to compute a simple cross-tabulation of two (or more) factors or variables in a dataframe
pivot_df = pd.crosstab(data['PaymentMethod'], data['Churn'])

# Plot the stacked bar chart
ax = pivot_df.plot(
    kind='bar',
    stacked=True, # stacked instead of side by side bars
    figsize=(10, 6),
    grid= False,
    color=['gold', 'violet']  # Set colors for 'No' and 'Yes'
)

# Set the title and labels using matplotlib
ax.set_title('Customer Payment Method distribution w.r.t. Churn', fontweight='bold')
ax.set_xlabel('Payment Method')
ax.set_ylabel('Number of Customers')

# Rename the legend title
ax.legend(title='Churn')

# Rotate x-axis labels
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
data[data["Gender"]== "Male"][["InternetService", "Churn"]].value_counts()
# to get the number of customers who churned based on the 
# InternetService and gender columns
# Out:
# InternetService  Churn
# DSL              No       992
# Fiber optic      No       910
# No               No       717
# Fiber optic      Yes      633
# DSL              Yes      240
# No               Yes       57
# Name: count, dtype: int64

# %%
data[data["Gender"]=="Female"][["InternetService", "Churn"]].value_counts()
# Out:
# InternetService  Churn
# DSL              No       965
# Fiber optic      No       889
# No               No       690
# Fiber optic      Yes      664
# DSL              Yes      219
# No               Yes       56
# Name: count, dtype: int64

# %% [markdown]
#  ---
# **Internet services:**
#
# Several customers choose the Fiber optic service and it's also evident that the customers who use Fiber optic have high churn rate, this might suggest a dissatisfaction with this type of internet service. Customers having DSL service are majority in number and have less churn rate compared to Fibre optic service.

# %%
labels = ["Female (No-Churn)", "Male (No-Churn)", "Female (Churn)", "Male (Churn)"]
DSL = [965, 992, 219, 240]
Fiber_optic = [889, 910, 664, 633]
NoInternet = [690, 717, 56, 57]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize=(10,6))

# Bars
ax.bar(x - width, DSL, width, label="DSL") # x - width means to shift the bars to the left
ax.bar(x, Fiber_optic, width, label="Fiber optic") # x means to keep the bars in the center
ax.bar(x + width, NoInternet, width, label="No Internet") # x + width means to shift the bars to the right

# Labels and title
ax.set_xticks(x) # it is used to set the locations of the ticks on the x-axis of the plot
ax.set_xticklabels(labels)
ax.set_xlabel("Customer Segments", fontweight= "bold")
ax.set_ylabel("Count", fontweight= "bold")
ax.set_title("Churn Distribution w.r.t. Internet Service and Gender", fontsize=16, fontweight="bold")
ax.legend()
plt.grid(False)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  ---
# **Dependent distribution:**
#
# Customers without dependents are more likely to churn

# %%
data[data["Churn"]== "Yes"][["Dependents", "Churn"]].value_counts()
# Out:
# Dependents  Churn
# No          Yes      1543
# Yes         Yes       326
# Name: count, dtype: int64

# %%
data[data["Churn"]== "No"][["Dependents", "Churn"]].value_counts()
# Out:
# Dependents  Churn
# No          No       3390
# Yes         No       1773
# Name: count, dtype: int64

# %%
color_map = {"Yes": "#D297FF", "No": "#E663FA"}

# Set figure size
plt.figure(figsize=(8,6))

# Grouped bar chart: x = Churn, hue = Contract
ax = sns.countplot(data=data, x= "Churn", hue= "Dependents", palette= color_map) 
# countplot is used to show the counts of observations in each categorical bin using bars of different colors

# for loop to Add value labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type="edge", fontsize=10) 

plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")
plt.title("Dependents Distribution w.r.t. Churn Status", fontsize=14, fontweight="bold")
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
color_map = {"Yes": "#FFEC5A", "No": "#00CCBE"}

# Set figure size
plt.figure(figsize=(8,6))

# Grouped bar chart: x = Churn, hue = Contract
ax = sns.countplot(data=data, x= "Churn", hue= "Partner", palette= color_map) 
# countplot is used to show the counts of observations in each categorical bin using bars of different colors

# for loop to Add value labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type="edge", fontsize=10) 

plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")
plt.title("Partner Distribution w.r.t. Churn Status", fontsize=14, fontweight="bold")
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
# **Senior Citizen:**
#
# Most of the senior citizens churn; the number of senior citizens are very less in over all customer base.

# %%
data[data["Churn"]== "Yes"][["SeniorCitizen", "Churn"]].value_counts()
#here we see
# Out:
# SeniorCitizen  Churn
# No             Yes      1393
# Yes            Yes       476
# Name: count, dtype: int64

# %%
data[data["SeniorCitizen"]== "Yes"][["Churn", "SeniorCitizen"]].value_counts()
# Out:
# Churn  SeniorCitizen
# No     Yes              666
# Yes    Yes              476
# Name: count, dtype: int64

# %%
data[data["Churn"]== "No"][["SeniorCitizen", "Churn"]].value_counts()
#
# Out:
# SeniorCitizen  Churn
# No             No       4497
# Yes            No        666
# Name: count, dtype: int64

# %%
data[data["SeniorCitizen"]== "No"][["Churn", "SeniorCitizen"]].value_counts()
# Out:
# Churn  SeniorCitizen
# No     No               4497
# Yes    No               1393
# Name: count, dtype: int64

# %%
color_map = {"Yes": "#CCC200", "No": "#80E8A6"}
pivot_df = pd.crosstab(data["SeniorCitizen"], data["Churn"]) #groupby based on senior citizen 

# Plot the stacked bar chart
ax = pivot_df.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    grid=False,
    color=color_map
)

# Set the title and labels using matplotlib
ax.set_title('Churn distribution w.r.t. Senior Citizen', fontweight='bold')
ax.set_xlabel('Senior Citizen')
ax.set_ylabel('Number of Customers')

# Rename the legend title
ax.legend(title='Churn')

# Rotate x-axis labels
plt.xticks(rotation=0)
for container in ax.containers:
    ax.bar_label(container, label_type="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
# **Online Security:**
#
# As shown in following graph, most customers churn due to lack of online security

# %%
color_map = sns.color_palette("colorblind", 3)

# Set figure size
plt.figure(figsize=(8,6))

# Grouped bar chart: x = Churn, hue = Contract
ax = sns.countplot(data=data, x= "Churn", hue= "OnlineSecurity", palette= color_map) 
# countplot is used to show the counts of observations in each categorical bin using bars of different colors

# for loop to Add value labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type="edge", fontsize=10) 

plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")
plt.title("Churn w.r.t Online Security", fontsize=14, fontweight="bold")
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
# **Paperless Billing:**
#
# Customers with Paperless Billing are most likely to churn.

# %%
color_map = {"Yes": "#FF6D5A", "No": "#00CCC2"}
pivot_df = pd.crosstab(data["Churn"], data["PaperlessBilling"]) #groupby based on churn 

# Plot the stacked bar chart
ax = pivot_df.plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    grid=False,
    color=color_map
)

# Set the title and labels using matplotlib
ax.set_title("Churn distribution w.r.t. Paperless Billing", fontweight="bold")
ax.set_xlabel("Churn Status")
ax.set_ylabel('Number of Customers')

# Rename the legend title
ax.legend(title= "PaperlessBilling")

# Rotate x-axis labels
plt.xticks(rotation=0)
for container in ax.containers:
    ax.bar_label(container, label_type="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
# **Tech support:**
#
# As shown in following chart, customers with no TechSupport are most likely to migrate to another service provider.

# %%
color_map = sns.color_palette("husl", 3)
plt.figure(figsize=(8,6))

# Grouped bar chart: x = Churn, hue = Contract
ax = sns.countplot(data=data, x= "Churn", hue= "TechSupport", palette= color_map) 
# countplot is used to show the counts of observations in each categorical bin using bars of different colors

# for loop to Add value labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type="edge", fontsize=10) 

plt.xlabel("Churn Status")
plt.ylabel("Number of Customers")
plt.title("Churn Distribution w.r.t Tech Support", fontsize=14, fontweight="bold")
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
color_map = {"Yes": "#0099CC", "No": "#8084E8"}
pivot_df = pd.crosstab(data["Churn"], data["PhoneService"]) #groupby based on churn 

# Plot the stacked bar chart
ax = pivot_df.plot(
    kind="bar",
    stacked=True,
    figsize=(10, 6),
    grid=False,
    color=color_map
)

# Set the title and labels using matplotlib
ax.set_title("Churn distribution w.r.t. Phone Service", fontweight="bold")
ax.set_xlabel("Churn Status")
ax.set_ylabel('Number of Customers')

# Rename the legend title
ax.legend(title= "PhoneService")

# Rotate x-axis labels
plt.xticks(rotation=0)
for container in ax.containers:
    ax.bar_label(container, label_type="center", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
#  ---
#  **Distribution w.r.t Charges and Tenure:**

# %%
sns.set_context("paper", font_scale = 1.1) 
# it means the font size of the text will be 1.1 times the default font size

ax = sns.kdeplot(data.MonthlyCharges[(data["Churn"] == "No")], 
                 color = "magenta", fill = True);
ax = sns.kdeplot(data.MonthlyCharges[(data["Churn"] == 'Yes')],
                 color = "green", fill = True);
# kdeplot is used to plot the Kernel Density Estimate plot of the 
# data it is a way to estimate the probability density function of a continuous random variable
# fill = True means the area under the curve will be colored
ax.legend(["Not Churn", "Churn"], loc = "upper right");
ax.set_ylabel('Density');
ax.set_xlabel('Monthly Charges');
ax.set_title('Distribution of monthly charges by churn');

# %%
ax = sns.kdeplot(data.TotalCharges[(data["Churn"] == 'No') ],
                color="blue", fill = True);
ax = sns.kdeplot(data.TotalCharges[(data["Churn"] == 'Yes') ],
                ax =ax, color="red", fill = True);
ax.legend(["Not Chuurn","Churn"],loc='upper right');
ax.set_ylabel('Density');
ax.set_xlabel('Total Charges');
ax.set_title('Distribution of total charges by churn');

# %%
# to create a box plot of the tenure column based on the Churn column
fig = px.box(data, x='Churn', y = 'Tenure') 

# Update yaxis properties
fig.update_yaxes(title_text='Tenure (Months)', row=1, col=1)
# Update xaxis properties
fig.update_xaxes(title_text='Churn', row=1, col=1)

# Update size and title
fig.update_layout(autosize = True, width = 750, height = 600,
    title_font = dict(size = 25, 
    family='Courier'), title='<b>Tenure vs Churn</b>',)
fig.show()

# %% [markdown]
# Customers with higher Monthly Charges are also more likely to churn.
# New customers are more likely to churn.
#
# ---

# %% [markdown]
# **New customers are more likely to churn**

# %%
data
# Out:
#       Gender SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0     Female            No     Yes         No       1           No
# 1       Male            No      No         No      34          Yes
# 2       Male            No      No         No       2          Yes
# 3       Male            No      No         No      45           No
# 4     Female            No      No         No       2          Yes
# ...      ...           ...     ...        ...     ...          ...
# 7038    Male            No     Yes        Yes      24          Yes
# 7039  Female            No     Yes        Yes      72          Yes
# 7040  Female            No     Yes        Yes      11           No
# 7041    Male           Yes     Yes         No       4          Yes
# 7042    Male            No      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...
